# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
qb = QuantBook()
qb.SetStartDate(2021, 1, 1)
future = qb.AddFuture(Futures.Indices.SP500EMini, Resolution.Minute, dataMappingMode=DataMappingMode.OpenInterest, contractDepthOffset=0)
print(future)
qb.setFilter(0,90)
symbols = qb.FutureChainProvider.GetFutureContractList(future.symbol, qb.StartDate)

# %%
print(future.Symbol)
trade_tick_history = qb.History[Tick](Futures.Indices.SP500EMini, timedelta(seconds=2), Resolution.Tick)

# %%
if future.HasData:
    Plot(future.Symbol.ID.Symbol,future.Symbol.ID.Symbol,future.Price)
else:
    print("No Data")
